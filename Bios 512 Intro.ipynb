# %% [markdown]
# Intro Comments for Bios 512

# %%
print('hello')
# Out:
# [1] "hello"

# %% [markdown]
# This is text

# %% [markdown]
# adding # will make the text added a header and ## a second header on (changes the size of the text in the markdown

# %% [markdown]
# Cells executed with shift enter (takes you to the next cell) or control enter (stay within the selected cell)

# %% [markdown]
# use markdown for text, or code for writing code

# %% [markdown]
# copy operation good for leaving current code but making edits in case you want to go back to the original before edits are made

# %% [markdown]
# must download to save progress, because if you try to save on the jupyter notebook it will delete when you are logged out of notebook
#
# remote machine only lasts as long as the session
#
# can click upload button to take code that you have been working on and downloaded to computer (in order to save it) and bring
