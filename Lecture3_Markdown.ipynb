# %% [markdown]
# # Markdown

# %% [markdown]
# ## Markdown is a useful syntax for marking up text for nice formatting
#
# https://daringfireball.net/projects/markdown/
# >This website provides an in depth dive into markdown
#
# > Markdown allows you to write using an easy-to-read, easy-to-write plain text format, then convert it to structurally valid XHTML (or HTML).

# %% [markdown]
# Markdown allows you to easily add heading, lists, images, etc. to you Jupyter notebooks and GitHub repositories.

# %% [markdown]
# ```markdown
# # This is how you format a heading
# ```

# %% [markdown]
# # This is how you format a heading

# %% [markdown]
# ```markdown
# - this is how
# - you format lists
#
#
# 1. and this is how
# 1. you format numbered lists
# 3. you can also explicitly number items
# ```

# %% [markdown]
# - this is how
# - you format lists
#   - indent
#
#
# 1. and this is how
# 1. you format numbered lists
# 1. you can also explicitly number items
#
# #don't need to increment manually, just add another 1 to put in new item in the middle of the list

# %% [markdown]
# Your `README.md` file will be rendered as the first page of your GitHub repo.
#
# [awesome GitHub readmes](https://github.com/matiassingers/awesome-readme)

# %% [markdown]
# Jupyter Lab allows you to edit and render markdown as you type.
