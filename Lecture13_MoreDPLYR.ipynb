# %% [markdown]
# # slice_max

# %%
library('tidyverse')
library('ggrepel')
library('patchwork')
options(repr.plot.res = 300, repr.plot.width = 7, repr.plot.height = 4)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.3     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.3     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
top.hwy = mpg %>% slice_max(hwy, n = 1)

top.hwy
# Out:
#   manufacturer model      displ year cyl trans      drv cty hwy fl class
# 1 volkswagen   jetta      1.9   1999 4   manual(m5) f   33  44  d  compact
# 2 volkswagen   new beetle 1.9   1999 4   manual(m5) f   35  44  d  subcompact

# %%
p = ggplot(mpg, aes(x = displ, y = hwy, color = class))

p = p + geom_point()

p = p + geom_text_repel(data = top.hwy, 
                        nudge_x = 1,
                        direction = 'y',
                        aes(label = manufacturer), 
                        color = 'black')  # this is important

p.hwy = p

p
# Out:
# plot without title

# %%
p = ggplot(mpg, aes(x = displ, y = cty, color = class))

p = p + geom_point()

p = p + geom_text_repel(data = top.hwy, 
                        nudge_x = 1,
                        direction = 'y',
                        aes(label = manufacturer), 
                        color = 'black')

p.cty = p

p
# Out:
# plot without title

# %%
# options(repr.plot.width = 12)
# p.hwy + p.cty

# %%
# p.hwy = p.hwy + theme(legend.position = 'none')

# p.hwy + p.cty

# %%
# options(repr.plot.width = 10, repr.plot.height = 4)

# p.hwy = p.hwy + ylim(c(0, 45))

# p.cty = p.cty + ylim(c(0, 45))

# p.hwy + p.cty

# %% [markdown]
# # Other summary functions

# %%
library(nycflights13)
library(tidyverse)

# %%
###Hint for assignment 3

#p = ggplot(weather, aes(x = temp))
#p = p + geom_histogram()
#p

#horizontal histogram with number of vaues they have each month
#p2 = ggplot(weather, aes(y = month))
#p2 = p2 + geom_histogram()
#p2


#Number of tempertaure values that exceed 50 degrees by month and use sum for aggregate function
weather  %>% 
    group_by(month)  %>% 
    summarize(max_temp = max(temp, na.rm = TRUE),
             obs = n(), 
             n_above_50 = sum(temp > 50, na.rm = TRUE),
             frac_above_50 = n_above_50 / n())  
    #if there are any missing values in dataset, the output will say NA after using a dplyr function
    #if you don't use na.rm = TRUE
# Out:
#    month max_temp obs  n_above_50 frac_above_50
# 1   1     64.40   2226  113       0.050763702
# 2   2     55.94   2010   10       0.004975124
# 3   3     60.08   2227  145       0.065110013
# 4   4     84.02   2159 1183       0.547938861
# 5   5     93.02   2232 1978       0.886200717
# 6   6     93.92   2160 2160       1.000000000
# 7   7    100.04   2228 2228       1.000000000
# 8   8     89.96   2217 2216       0.999548940
# 9   9     95.00   2159 2132       0.987494210
# 10 10     89.06   2212 1900       0.858951175
# 11 11     71.06   2141  674       0.314806165
# 12 12     71.60   2144  289       0.134794776

# %%
c(100, 45, 50, 60) >50
sum(c(100, 45, 50, 60) >50)
#this shows what the sum function does when a > or < is used
#it adds all of the TRUE values together and gives a total output
# Out:
# [1]  TRUE FALSE FALSE  TRUE
# [1] 2

# %% [markdown]
# # Back to Regular Lecture

# %%
weather %>% head
# Out:
#   origin year month day hour temp  dewp  humid wind_dir wind_speed wind_gust
# 1 EWR    2013 1     1   1    39.02 26.06 59.37 270      10.35702   NA
# 2 EWR    2013 1     1   2    39.02 26.96 61.63 250       8.05546   NA
# 3 EWR    2013 1     1   3    39.02 28.04 64.43 240      11.50780   NA
# 4 EWR    2013 1     1   4    39.92 28.04 62.21 250      12.65858   NA
# 5 EWR    2013 1     1   5    39.02 28.04 64.43 260      12.65858   NA
# 6 EWR    2013 1     1   6    37.94 28.04 67.21 240      11.50780   NA
#   precip pressure visib time_hour
# 1 0      1012.0   10    2013-01-01 01:00:00
# 2 0      1012.3   10    2013-01-01 02:00:00
# 3 0      1012.5   10    2013-01-01 03:00:00
# 4 0      1012.2   10    2013-01-01 04:00:00
# 5 0      1011.9   10    2013-01-01 05:00:00
# 6 0      1012.4   10    2013-01-01 06:00:00

# %%
p = ggplot(weather, aes(x = month, y = temp))

p = p + geom_point(alpha = 0.15, 
                   position = position_jitter(h = 0, w = 0.4))

p
# Out:
# Warning message:
# “Removed 1 rows containing missing values (geom_point).”
# plot without title

# %% [markdown]
# ## mean, median, max, min

# %%
 weather %>%
     group_by(month) %>%
     summarize(median.temp = median(temp)) %>%
     arrange(median.temp)
# Out:
#    month median.temp
# 1   2    33.98
# 2   1    37.04
# 3  12    37.04
# 4   3    39.02
# 5  11    44.96
# 6   4    51.98
# 7   5    60.98
# 8  10    60.98
# 9   9    66.92
# 10  6    71.96
# 11  7    78.98
# 12  8       NA

# %% [markdown]
# ## sd, IQR

# %%
 weather %>%
     group_by(month) %>%
     summarize(sd.temp = sd(temp)) %>%
     arrange(sd.temp)
# Out:
#    month sd.temp
# 1   3     6.249278
# 2   2     6.982378
# 3   7     7.119899
# 4   6     7.546371
# 5   9     8.465902
# 6   4     8.786168
# 7  10     8.846035
# 8   5     9.681644
# 9  12     9.982432
# 10  1    10.224635
# 11 11    10.443805
# 12  8           NA

# %% [markdown]
# # Data import/export

# %% [markdown]
# ## readr

# %%
# ?readr

# %%
# ?read_csv

# %%
# ?write_csv

# %%
library('nycflights13')

weather %>% head
# Out:
#   origin year month day hour temp  dewp  humid wind_dir wind_speed wind_gust
# 1 EWR    2013 1     1   1    39.02 26.06 59.37 270      10.35702   NA
# 2 EWR    2013 1     1   2    39.02 26.96 61.63 250       8.05546   NA
# 3 EWR    2013 1     1   3    39.02 28.04 64.43 240      11.50780   NA
# 4 EWR    2013 1     1   4    39.92 28.04 62.21 250      12.65858   NA
# 5 EWR    2013 1     1   5    39.02 28.04 64.43 260      12.65858   NA
# 6 EWR    2013 1     1   6    37.94 28.04 67.21 240      11.50780   NA
#   precip pressure visib time_hour
# 1 0      1012.0   10    2013-01-01 01:00:00
# 2 0      1012.3   10    2013-01-01 02:00:00
# 3 0      1012.5   10    2013-01-01 03:00:00
# 4 0      1012.2   10    2013-01-01 04:00:00
# 5 0      1011.9   10    2013-01-01 05:00:00
# 6 0      1012.4   10    2013-01-01 06:00:00

# %%
weather %>% write_csv('weather.csv')

# %%
weather_from_file = read_csv('weather.csv', col_types = cols())

# %%
system("head weather.csv", intern=TRUE)
# Out:
#  [1] "origin,year,month,day,hour,temp,dewp,humid,wind_dir,wind_speed,wind_gust,precip,pressure,visib,time_hour"
#  [2] "EWR,2013,1,1,1,39.02,26.06,59.37,270,10.357019999999999,NA,0,1012,10,2013-01-01T06:00:00Z"
#  [3] "EWR,2013,1,1,2,39.02,26.96,61.63,250,8.05546,NA,0,1012.3,10,2013-01-01T07:00:00Z"
#  [4] "EWR,2013,1,1,3,39.02,28.04,64.43,240,11.5078,NA,0,1012.5,10,2013-01-01T08:00:00Z"
#  [5] "EWR,2013,1,1,4,39.92,28.04,62.21,250,12.658579999999999,NA,0,1012.2,10,2013-01-01T09:00:00Z"
#  [6] "EWR,2013,1,1,5,39.02,28.04,64.43,260,12.658579999999999,NA,0,1011.9,10,2013-01-01T10:00:00Z"
#  [7] "EWR,2013,1,1,6,37.94,28.04,67.21,240,11.5078,NA,0,1012.4,10,2013-01-01T11:00:00Z"
#  [8] "EWR,2013,1,1,7,39.02,28.04,64.43,240,14.960139999999999,NA,0,1012.2,10,2013-01-01T12:00:00Z"
#  [9] "EWR,2013,1,1,8,39.92,28.04,62.21,250,10.357019999999999,NA,0,1012.2,10,2013-01-01T13:00:00Z"
# [10] "EWR,2013,1,1,9,39.92,28.04,62.21,260,14.960139999999999,NA,0,1012.7,10,2013-01-01T14:00:00Z"

# %% [markdown]
# ## Reading data directly from URL

# %%
# also works with read.csv

marathon_df = read_csv('https://raw.githubusercontent.com/chuckpr/BIOS512/main/in-class-exercises/data/marathon.csv',
                      col_types = cols())
#adding col_types = cols() it turns off the note it gives about the columns when it is reading in info


# marathon_df = read_csv(
#     'https://raw.githubusercontent.com/chuckpr/BIOS512/main/in-class-exercises/data/marathon.csv',
#     col_types = cols()
# )

# %%
marathon_df %>% head # try with print

print(marathon_df)
# Out:
#   year name                       country       time       race.time MF
# 1 2019 Lawrence Cherono           Kenya         2H 7M 57S  2.132500  Men's
# 2 2018 Yuki Kawauchi              Japan         2H 15M 58S 2.266111  Men's
# 3 2017 Geoffrey Kirui             Kenya         2H 9M 37S  2.160278  Men's
# 4 2016 Lemi Berhanu               Ethiopia      2H 12M 45S 2.212500  Men's
# 5 2015 Lelisa Desisa              Ethiopia      2H 9M 17S  2.154722  Men's
# 6 2014 Mebrahtom "Meb" Keflezighi United States 2H 8M 37S  2.143611  Men's
#   country.simple
# 1 Kenya
# 2 Japan
# 3 Kenya
# 4 Ethiopia
# 5 Ethiopia
# 6 United States
# # A tibble: 171 × 7
#     year name                           country time  race.time MF    country.simple
#    <dbl> <chr>                          <chr>   <chr>     <dbl> <chr> <chr>
#  1  2019 "Lawrence Cherono"             Kenya   2H 7…      2.13 Men's Kenya
#  2  2018 "Yuki Kawauchi"                Japan   2H 1…      2.27 Men's Japan
#  3  2017 "Geoffrey Kirui"               Kenya   2H 9…      2.16 Men's Kenya
#  4  2016 "Lemi Berhanu"                 Ethiop… 2H 1…      2.21 Men's Ethiopia
#  5  2015 "Lelisa Desisa"                Ethiop… 2H 9…      2.15 Men's Ethiopia
#  6  2014 "Mebrahtom \"Meb\" Keflezighi" United… 2H 8…      2.14 Men's United States
#  7  2013 "Lelisa Desisa"                Ethiop… 2H 1…      2.17 Men's Ethiopia
#  8  2012 "Wesley Korir"                 Kenya   2H 1…      2.21 Men's Kenya
#  9  2011 "Geoffrey Mutai"               Kenya   2H 3…      2.05 Men's Kenya
# 10  2010 "Robert Kiprono Cheruiyot"     Kenya   2H 5…      2.10 Men's Kenya
# # … with 161 more rows
